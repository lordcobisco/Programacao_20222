# %% [markdown]
# <a href="https://colab.research.google.com/github/erickaraiane/Programacao_20222/blob/main/AULA6ERICKA_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#AULA CONTEXTUALIZADA 6

print('Guia para procedimento de cirurgia esterotáxica')
anestesia= ('anestesiar animal')
anestesiado = str(input('o animal esta devidamente anestesiado?'))
if anestesiado=='s': 
  print('continuar cirurgia')
if anestesia==('n'):
  print('so iniciar depois que o animal estiver completamente anestesiado')
regiaoAgulha= ('anteroPosterior','ateroLateral','dorsoVentral')
#regioes
posicionamentoinicial= [6.42, 3.23, 4.2]
print('posicionamento inicial', posicionamentoinicial)
#calculo para posicionamento
AP= posicionamentoinicial[0] - 0.42
DV= posicionamentoinicial[2] - 0.2
hemisferio= int(input("Qual dos hemisférios vai ser colocada a primeira cânula?(1 para direito, 2 para esquerdo) 1 ou 0"))

if(hemisferio==1):
    LL= posicionamentoinicial[1] + 0.30
else:
    LL= posicionamentoinicial[1] - 0.30

posicionamentocalculado= {"AP": AP, "LL": LL, "DV": DV}
print("Regiões de posicionamento da agulha:", regiaoAgulha  )
print("Posicionamento calculado da agulha:", posicionamentocalculado)
print("Posicionando...")
print("Agulha posicionada!")

distanciAgulhaMeninge=5

for i in range(distanciAgulhaMeninge):
    ang=45
    print("descer broca em ângulo de ", ang, "°")
    

print("perfuração meninge. introduzir cânula-guia.")

for i in range(int(DV)):
    print("introduzindo cânula-guia")

fluido= int(input("está saindo algum fluido pelo orifício do crânio? 1 ou 0"))
if(fluido==1):
    print("instruções: drenar liquido")
    print("faça uma mistura de acrílico polimerizante com o solvente." )
else:
    print("prossiga")

textura=0

while(textura==0):
    textura= int(input("a textura esta no ponto? 1 ou 0"))
    if(textura==0):
        print("continue misturando")
print("com essa mistura faça mistura abrangendo o crânio, a cânula-guia e o parafuso e deixe secar.")

#SEGUNDA CANULA
print("introduzir cânula guia ")

if(hemisferio==1):
    LL_oposto= posicionamentoinicial[1] - 0.30
else:
    LL_oposto= posicionamentoinicial[1] + 0.30
posicionamentooposto= {"AP": AP,"LL": LL_oposto,"DV": DV}

print("levantar braço do estereotáxico")
print("posicionamento da segunda agulha:", posicionamentooposto)
  
for j in range(int(DV)):
    print("introduzindo a segunda cânula-guia")

fluido2= int(input("está saindo algum fluido pelo orifício do crânio? 1 ou 0"))
if(fluido2==1):
    print("instruções: drenar liquido")
    print("Faça uma mistura de acrílico polimerizante com o solvente.")
else:
    print("Prossiga. Faça uma mistura de acrílico polimerizante com o solvente")

textura2=0

while(textura2==0):
    textura2= int(input("a textura da mistura está espessa e maleável?"))
    if(textura2==0):
        print("continue misturando")
print("com essa mistura faça mistura abrangendo o crânio, a cânula-guia e o parafuso e deixe secar")

print("Fim da cirurgia")
acordou=int(input('animal acordou? 1 ou 0'))
if(acordou==0):
    while(acordou==0):
        if(acordou==1):
            print('Colocar o animal de volta a sua caixa-moradia')
            break
        acordou=int(input("Animal acordou? 1 ou 0"))
else:
  print('Colocar o animal de volta a sua caixa-moradia')
# Out:
# Guia para procedimento de cirurgia esterotáxica
# o animal esta devidamente anestesiado?s
# continuar cirurgia
# posicionamento inicial [6.42, 3.23, 4.2]
# Qual dos hemisférios vai ser colocada a primeira cânula?(1 para direito, 2 para esquerdo) 1 ou 01
# Regiões de posicionamento da agulha: ('anteroPosterior', 'ateroLateral', 'dorsoVentral')
# Posicionamento calculado da agulha: {'AP': 6.0, 'LL': 3.53, 'DV': 4.0}
# Posicionando...
# Agulha posicionada!
# descer broca em ângulo de  45 °
# descer broca em ângulo de  45 °
# descer broca em ângulo de  45 °
# descer broca em ângulo de  45 °
# descer broca em ângulo de  45 °
# perfuração meninge. introduzir cânula-guia.
# introduzindo cânula-guia
# introduzindo cânula-guia
# introduzindo cânula-guia
# introduzindo cânula-guia
# está saindo algum fluido pelo orifício do crânio? 1 ou 00
# prossiga
# a textura esta no ponto? 1 ou 01
# com essa mistura faça mistura abrangendo o crânio, a cânula-guia e o parafuso e deixe secar.
# ...
