# %% [markdown]
# <a href="https://colab.research.google.com/github/catherinemesquita/PROGRAMACAO/blob/main/ATIV_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
inicio= 'Cirurgia estereotáxica para ratos'
print(inicio)

anestesia='Verificar se o animal está devidamente anestesiado.'
print(anestesia)


anestesias= input('O animal está completamnete sedado? Digite s ou n:')
if anestesias == 's' and anestesias != 'n':
    print('Continuar')
if anestesias == 'n' and anestesias != 's' :
     print('Aprofundar anestesia')


print('Posicionar animal no estereotáxico')
print('Encaixar as barras de suporte no ouvido externo do animal')


posicao=input('O animal está bem posicionado? Digite s ou n:')
if posicao == 's':
  certo= input('A cabeça do animal está reta? Digite s ou n:')
  if certo == 's':
    print('Prosseguir para limpeza do campo de trabalho')
  if certo == 'n':
    print('Ajuste a cabeça do animal até que fique reta.')
if posicao == 'n':
  print('Posicione corretamente o animal')

print('Limpeza do campo de trabalho')
print('Realizar tricotomia na cabeça')
print('Realizar incisão')
print('Reirar tecidos moles até expor o crânio')
print('Limpar o crânio com H2O2 10 volumes')

limpeza=input('O crânio está completamente limpo? Digite s ou n:')
if limpeza == 's':
  print('Aplicar poliacrilato no perímetro externo para hemostasia.')
if limpeza == 'n':
  while limpeza == 'n':
    print('Limpar até que o campo de trabalho esteja completamente limpo')
    limpeza_2=input('O crânio está completamente limpo? Digite s ou n:')
    if limpeza_2 == 's': break

print('Escolha três pontos para fixar os parafusos.')
print('Dê três voltas em cada parafuso')

voltas=0
while voltas <=3:
  print(voltas)
  voltas +=1
  if voltas == 4: break

print('Parafusos posicionados corretamente')
posCaninicial={'AP':6.42,'LLa':3.33,'LLb':3.33,'DV':4.2}
posCaninicial['AP']=6.42-0.42
posCaninicial['LLa']=3.33+0.3
posCaninicial['LLb']=3.33-0.30
posCaninicial['DV']=4.2-0.2

canPos={'AP':6,'LLa':3.63,'LLb':3.03,'DV':4}
posicaoCan=('AP','LLa','LLb','DV')
print('Início do posicionamento das cânulas-guia')
for i in range(len(posicaoCan)):
  print(posicaoCan[i],':',posCaninicial[posicaoCan[i]])

print('Furar com a broca o crânio para inserção das cânulas')
print('Atenção! Cuidado para não perfurar as meninges!')
print('Apoie a mão que segura a broca contra o assoalho ou ao estereotáxico e perfure o crânio a +- 45 graus de angulação')

print('Introdução da cânula')
prof=int(input('Digite o DV da cânula:'))
if prof == 4:
  print('A cânula será aprofundada 4cm')
  if prof == 4:
    print('Aprofundando:')
    profundidade=0
    while profundidade <=4:
      print(profundidade)
      profundidade +=1
      if profundidade == 5: break 
else:
  print('O DV digitado está incorreto')

print('Cânula aprofundada com sucesso!')

sang=input('Há sangramento? Digite s ou n:')
if sang == 's':
  print('Realize hemostasia com papel')
if sang == 'n':
  print('Prossiga para a próxima etapa')
if sang !=('s' and 'n'):
  print('Erro! Digite s ou n')


print('Mistura para capacete')
print('Adicione 3g de acrílico polimerizante com 1mL de solvente e misture')

while(True):
  sang=input('A mistura está com textura expessa, porém maleável? Digite s ou n:')
  if(sang == 's'):
    print('Cobrir a cânula-guia e parafusos')
    break
  else:
    print('Adicione mais acrílico')

print('Espere secar até ficar suficientemente rígido') 
while(True):   
  duro=input('O acrílico está rígido? Digite s ou n:')
  if(duro == 's'): 
    break
  else:
    print('Aguarde mais um pouco até endurecer')

print('Fixação da outra cânula')
print('Levantar levemente o braço do estereotáxico cuidando para que a cânula-guia previamente fixada não se movimente')

prof=int(input('Digite o DV da cânula 2:'))
if prof == 4:
  print('A cânula será aprofundada 4cm')
  if prof == 4:
    print('Aprofundando:')
    profundidade=0
    while profundidade <=4:
      print(profundidade)
      profundidade +=1
      if profundidade == 5: break 
else:
  print('O DV digitado está incorreto')

print('Cânula 2 aprofundada com sucesso!')

sang=input('Há sangramento? Digite s ou n:')
if sang == 's':
  print('Realize hemostasia com papel')
if sang == 'n':
  print('Prossiga para a próxima etapa')
if sang !=('s' and 'n'):
  print('Erro! Digite s ou n')


print('Mistura para capacete')
print('Adicione 3g de acrílico polimerizante com 1mL de solvente e misture')

while(True):
  sang=input('A mistura está com textura expessa, porém maleável? Digite s ou n:')
  if(sang == 's'):
    print('Cobrir a cânula-guia e parafusos')
    break
  else:
    print('Adicione mais acrílico')

print('Espere secar até ficar suficientemente rígido') 
while(True):   
  duro=input('O acrílico está rígido? Digite s ou n:')
  if(duro == 's'): 
    break
  else:
    print('Aguarde mais um pouco até endurecer')

print('Fixação de cânulas finalizada com sucesso!')
print('Acmode o animal em uma caixa com lâmpada para mantê-lo aquecido até que acorde')

while(True):
  acorda=input('O animal acordou? Digite s ou n:')
  if(acorda == 's'):
    print('Colocar o animal de volta em sua caixa-moradia')
    break
  else:
    print('Aguarde o animal despertar')

print('Cirurgia estereotaxica realizada com sucesso!')
print('Final do programa.')
# Out:
# Cirurgia estereotáxica para ratos
# Fixação de cânulas finalizada com sucesso!
# Acmode o animal em uma caixa com lâmpada para mantê-lo aquecido até que acorde
# O animal acordou? Digite s ou n:n
# Aguarde o animal despertar
# O animal acordou? Digite s ou n:s
# Colocar o animal de volta em sua caixa-moradia
