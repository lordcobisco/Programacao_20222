# %% [markdown]
# <a href="https://colab.research.google.com/github/alineroberta/Programacao_20222/blob/main/Atividade_aula_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ATIVIDADE - AULA 3

# %% [markdown]
# a) Crie as variáveis necessárias para que o programa funcione corretamente.
#
# b) Inicialize as variáveis com valores padrão adequados.

# %%
tipo_de_sonda = 'sonda de DNA' 
resolução_da_imagem = '300 dpi'
largura_imagem = '1600 pixels' #Número de pontos que formarão a imagem e o formato dela
altura_imagem = '1200 pixels'  ##Número de pontos que formarão a imagem e o formato dela
tipo_de_célula = 'sangue'
ganho_saturação = '255' #Aumento da intensidade dos pixels por aumento da voltagem no PMT
zoom = '5x' #Aumento da magnificação da imagem obtido pela diminuição da área varrida pelo laser
tamanho_da_imagem = '10,5 x 3,43'
tamanho_do_arquivo = '53 kb'
speed = '400 Hz' #Número de linhas lidas por segundo pela varredura do laser

# %% [markdown]
# c) Crie uma pequena mensagem de apresentação do programa para realizar uma interface com o usuário. Ex.: “Esse programa tem como objetivo receber dados para ...”

# %%
print('Esse programa tem como objetivo receber dados para gerar imagem do microscópio')
# Out:
# Esse programa tem como objetivo receber dados para gerar imagem do microscópio

# %% [markdown]
# d) Solicite algumas informações necessárias para a configuração de um microscópio dessa natureza. Buscar pelo menos 10 itens para essas informações de entrada. Ex.: resolução da imagem desejada, tipo de célula a ser escaneada, faixa de iluminação necessária.
#
# e) Para cada informação digitada, apresente na tela a seguinte mensagem: “Houve alteração na variável inserida? ”. Após a mensagem, apresentar verdadeiro ou falso com base no que foi digitado pelo usuário e o que estava armazenado na variável. Obs.: Não deve ser utilizado if aqui

# %%
novo_tipo_de_sonda = input('- sonda utilizada:  ')
print ('Houve alteração na variável inserida? ',  tipo_de_sonda == novo_tipo_de_sonda)
print()
novo_resolução_da_imagem = input ('- resolução da imagem:  ')
print ('Houve alteração na variável inserida? ', resolução_da_imagem == novo_resolução_da_imagem)
print()
novo_largura_imagem = input ('- largura da imagem:  ')
print ('Houve alteração na variável inserida? ', novo_largura_imagem == largura_imagem)
print()
novo_tipo_de_célula = input ('- tipo de célula:  ')
print ('Houve alteração na variável inserida? ', novo_tipo_de_célula == tipo_de_célula)
print()
novo_ganho_saturação = input ('- ganho de saturação:  ')
print ('Houve alteração na variável inserida? ', novo_ganho_saturação == ganho_saturação)
print()
novo_zoom = input ('- zoom:  ')
print ('Houve alteração na variável inserida? ', novo_zoom == zoom)
print()
novo_tamanho_da_imagem = input ('- tamanho da imagem:  ')
print ('Houve alteração na variável inserida? ', novo_tamanho_da_imagem == tamanho_da_imagem)
print()
novo_tamanho_do_arquivo = input ('- tamanho do arquivo:  ')
print ('Houve alteração na variável inserida? ', novo_tamanho_do_arquivo == tamanho_do_arquivo)
print()
novo_speed = input ('- speed:  ')
print ('Houve alteração na variável inserida? ', novo_speed == speed)
# Out:
# - sonda utilizada:  sonda de DNA
# Houve alteração na variável inserida?  True
#
# - resolução da imagem:  300 dpi
# Houve alteração na variável inserida?  True
#
# - largura da imagem:  xxx
# Houve alteração na variável inserida?  False
#
# - tipo de célula:  miocárdio
# Houve alteração na variável inserida?  False
#
# - ganho de saturação:  9
# Houve alteração na variável inserida?  False
#
# - zoom:  5x
# Houve alteração na variável inserida?  False
#
# - tamanho da imagem:  10,5 x 3,43
# Houve alteração na variável inserida?  True
#
# - tamanho do arquivo:  +
# Houve alteração na variável inserida?  False
#
# - speed:  400 Hz
# Houve alteração na variável inserida?  True

# %% [markdown]
# f) Retorne ao usuário de forma organizada as informações que foram digitadas. Ex.: “As informações de configurações setadas pelo usuário são: ...”

# %%
print('As informações de configurações setadas pelo usuário são:')
print(novo_tipo_de_sonda);print(novo_resolução_da_imagem)
print(novo_largura_imagem)
print(novo_tipo_de_célula)
print(novo_ganho_saturação)
print(novo_zoom)
print(novo_tamanho_da_imagem)
print(novo_tamanho_do_arquivo)
print(novo_speed)
# Out:
# As informações de configurações setadas pelo usuário são:
# sonda de DNA
# 300 dpi
# xxx
# miocárdio
# 9
# 5x
# 10,5 x 3,43
# +
# 400 Hz

# %% [markdown]
# g) Após setada as configurações iniciais o usuário deve utilizar dois caracteres para a calibração do equipamento no sentido horizontal. Para isso, ele deve apertar a tecla correspondente à primeira letra do seu nome 10x e à última letra do seu nome 10x.
#
# h) Imediatamente após apertar a tecla o programa deve apresentar na tela que a informação foi corretamente digitada e mostrar o caractere pressionado.

# %%
senha_horizontal = 'aaaaaaaaaaeeeeeeeeee'
print('vamos iniciar a calibação do equipamento...')
senha_inserida_horizontal = (input('aperte 10x e letra A e 10x a letra E:  '))
print('senha foi corretamente digitada!  ', senha_inserida_horizontal== senha_horizontal)
print (senha_inserida_horizontal)
# Out:
# vamos iniciar a calibação do equipamento...
# aperte 10x e letra A e 10x a letra E:  44444
# senha foi corretamente digitada!   False
# 44444

# %% [markdown]
# i) Na sequência o usuário deve utilizar dois caracteres para a calibração do equipamento no sentido vertical. Para isso, ele deve apertar a tecla correspondente à segunda letra do seu nome 10x e à penúltima letra do seu nome 10x.
#
# j) Imediatamente após apertar a tecla o programa deve apresentar na tela que a informação foi corretamente digitada e mostrar o caractere pressionado.

# %%
senha_vertical = 'llllllllllnnnnnnnnnn'
senha_inserida_vertical= (input('aperte 10x a letra L e 10x a letra N:  '))
print('senha foi corretamente digitada!  ', senha_inserida_vertical == senha_vertical)
print (senha_inserida_vertical)
# Out:
# aperte 10x a letra L e 10x a letra N:  00000
# senha foi corretamente digitada!   False
# 00000

# %% [markdown]
# k) Finalmente, o programa deverá apresentar na tela que houve o término da calibração do sistema.

# %%
print ('prontinho, calibração finalizada!')
# Out:
# prontinho, calibração finalizada!

# %% [markdown]
# l) Para verificar que o programa está funcionando corretamente, execute-o colocando um breakpoint na linha 15. Tire um print da tela mostrando a linha parada e as informações armazenadas nas variáveis até então.

# %% [markdown]
# ![debug.png](data:image/png;base64,...)
