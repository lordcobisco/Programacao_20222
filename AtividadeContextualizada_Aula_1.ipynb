# %% [markdown]
# <a href="https://colab.research.google.com/github/alineroberta/Programacao_20222/blob/main/AtividadeContextualizada_Aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atividade - Aula 1

# %% [markdown]
# ### 1. Descreva de forma narrativa (slide 27) com a maior quantidade de detalhes possível (Interação paciente máquina, setup, comunicação com hardware, o que estiver mais familiarizado) como se daria a utilização do Lokomat® e ZeroG®.

# %% [markdown]
# **ZeroG**

# %%
Vestir o colete no paciente
Afivelar os cintos às pernas do paciente. Se os cintos estiverem folgados, apertá-los. Se estiverem apertados corretamente, seguir para a próxima etapa.
Prender os dois ganchos na barra do ZeroG. 
Pegar o controle
Selecionar a opção que vai iniciar: distance mode, velocity mode
Clicar em “iniciar”
Paciente inicia marcha
Se o paciente andar, o ZeroG acompanha, se não, o ZeroG para.
Se o paciente cair ou desequilibrar (sensor detectar perda de 4 polegadas), ativar o ZeroG (força oposta)
Fim

# %% [markdown]
# **Lokomat**

# %%
Solicitar para inserir peso do paciente
Solicitar para Inserir altura do paciente
Orientar para colocar paciente na esteira
ao apertar botão no controle, descer a barra
Se todos os ganchos estiverem posicionados (=4), então seguir para próxima etapa. Se não, inserir pop-up “Prenda todos os ganchos”.
Ao apertar botão no controle, elevar a barra até que o paciente esteja suspenso
Ao clicar em “training” > “start positioning”, fazer posição de caminhada (um pé atrás e outro na frente)
Ao clicar em “start”, iniciar movimentos de caminhada
Apertar em “descer” -> barra começa a baixar e os pé e voltam a tocar o chão
Repita a caminhada do Logomat até que seja apertado o botão de “stop” no computador
Fim

# %% [markdown]
# ### 2. A partir das informações colocadas no texto da questão 1, destacar o que seriam memória, processamento, entrada/saída:

# %% [markdown]
# **MEMÓRIA**

# %%
#LOKOMAT
- Peso do paciente (real)
- Altura do oaciente (real)
- Controle da Barra para Descer (lógico/ boleano)
- Ganchos da Barra (inteiro)
- Controle da Barra para Subir (lógico)
- StartPositioning (lógico)
- Start (lógico)
- Stop (lógico)

# %%
#ZEROG
- Peso do paciente (real)
- Altura do oaciente (real)
- Controle da Barra para Descer (lógico/ boleano)
- Ganchos da Barra (inteiro)
- Controle da Barra para Subir (lógico)
- StartPositioning (lógico)
- Start (lógico)
- Stop (lógico)

# %% [markdown]
# **PROCESSAMENTO**

# %%
#LOKOMAT
- Inserir peso do paciente
- Inserir altura do paciente
- Orientação para colocar paciente na esteira
- Descer/subir a barra
- inserir pop-up “Prenda todos os ganchos”.
- fazer posição de caminhada
- iniciar movimentos de caminhada

# %%
#ZEROG
- Pop-up para orientar vestir o colete no paciente e  prender os cintos
- Marcha no paciente em distance mode e velocity mode
- ZeroG acompanha os passos do paciente
- ZeroG fazer força oposta quando o paciente cair/desequilibrar

# %% [markdown]
# **ENTRADA/SAÍDA**

# %%
#LOKOMAT
- Saída: Lokomat e esteira, monitor
- Entrada: Controle da barra

# %%
#ZEROG
- Saída: ZeroG
- Entrada: Controle do ZeroG, sensor de peso, sensor de movimento (?)

# %% [markdown]
# ### 3. Converter as informações compiladas nas questões 1, 2 e 3 em um diagrama de blocos conforme apresentado no slide 28.

# %% [markdown]
# **Lokomat**

# %% [markdown]
# ![DIAGRAMA_LOKOMAT.png](data:image/png;base64,...)

# %% [markdown]
# **ZeroG**

# %% [markdown]
# ![DIAGRAMA_ZEROG.png](data:image/png;base64,...)

# %% [markdown]
# ### 4.	Converter as informações compiladas nas questões 1, 2 e 3 em um pseudocódigo conforme apresentado no slide 30

# %% [markdown]
# **ZeroG**

# %%
# Vestir o colete no paciente. Afivelar os cintos às pernas do paciente. Se os cintos e ganchos estiverem corretamente colocados, seguir para a próxima etapa. 
Escreva “Vista o colete no paciente e garanta que todos os cintos e ganchos foram colocados corretamente”

#Pegar o controle. Selecionar a opção que vai iniciar: distance mode, velocity mode
	Var DistanceMode: lógico
	Var VelocityMode: lógico
	Leia DistanceMode, VelocityMode, Marcha
	Se DistanceMode = 1 então
		Execute <Marcha em velocidade lenta>
	Se VelocityMode = 1 então
		Execute <Marcha em velocidade mais rápida>
	
# Se o paciente andar, o ZeroG acompanha, se não, o ZeroG para.
Var MarchaPaciente: real #passos
Var DistZeroG: real
	Leia MarchaPaciente, DistZeroG
	Se MarchaPaciente = x então
		Execute DistZeroG = x

# Se o paciente cair ou desequilibrar (sensor detectar perda de altura/resistência), ativar o ZeroG (força oposta)
Var PesoPaciente: real #passos
Var ForçaZeroG: real
	Leia PesoPaciente, ForçaZeroG
	Se PesoPaciente= y então
		Execute ForçaZeroG = y

# Fim
Escreva “Fim do programa”

# %% [markdown]
# **Lokomat**

# %%
# Inserir peso e altura do paciente
Algoritmo Funcionamento_Lokomat
Var PesoPaciente: real
#solicitar para inserir peso do paciente
Var AlturaPaciente: real
#solicitar para inserir altura do paciente

# Colocar paciente na esteira
Escreva “posicione o paciente na esteira”

# Apertar botão no controle para descer a barra
Var ControleBarraDescer: lógico #boleano: 0 = off, 1 = on
Leia ControleBarraDescer, 
Se ControleBarraDescer = 1 Então 
Execute <descer a barra> até <os pés do paciente toquem o chão>

# Se todos os ganchos estiverem posicionados (=4), então seguir para próxima etapa. Se não, inserir pop-up “Prenda todos os ganchos”.
Var GanchosBarra: inteiro
Leia GanchosBarra
Se GanchosBarra < 4 Então #tem 4 ganchos
Escreva “Prenda todos os ganchos na barra”

# Ao apertar botão no controle, elevar a barra até que o paciente esteja suspenso 
Var ControleBarraSubir: lógico #boleano: 0 = off, 1 = on
Leia ControleBarrasSubir, 
Se ControleBarraSubir = 1 Então 
Execute <subir a barra> até <os pés do paciente não toquem o chão”

# Ao clicar em “training” > “start positioning”, fazer posição de caminhada (um pé atrás e outro na frente)
Var StartPositioning: lógico
Leia StartPositioning
Se StartPositioning = 1 então
	Execute <fazer posição de caminhada>

# Ao clicar em “start”, iniciar movimentos de caminhada. Repita a caminhada do Logomat até que seja apertado o botão de “stop” no computador
	Var Start: lógico
	Var Stop: lógico
Leia Start, Stop
Se Start= 1 então
	Execute <iniciar movimentos de caminhada> até <Stop = 1>

# Apertar em “descer” -> barra começa a baixar e os pés e voltam a tocar o chão (tarefa já programada anteriormente)

# Fim
Escreva “Fim do programa”
